# %%
include("examples.jl")

using .Examples

# %%
exponential_sequence_example()
# Out:
# Plot(...)

# %%
normal_sequence_example()
# Out:
# Plot(...)

# %%
random_sequence_example()
# Out:
# Plot(...)

# %%
decision_boundary_example()
# Out:
# Plot(...)
